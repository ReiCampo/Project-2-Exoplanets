# %%
import numpy as np
from scipy import integrate
from astropy import constants as const
from astropy import units as u
import plotter as p #plotter function
import gravSolve as gs #gravity solver function
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# the following data comes from http://three-body.ipb.ac.rs/sol.php?id=5
M1 = 1 
M2 = 1
M3 = 1

p1 = 0.080584
p2 = 0.588836
P = 21.270975

body1Pos = [-1,0,0] #(x,y,z)
body1Velo = [p1,p2,0] #(vx,vy,vz)

body2Pos = [1,0,0] #(x,y,z)
body2Velo = [p1,p2,0] #(vx,vy,vz)

body3Pos = [0,0,0]
body3Velo= [-2*p1,-2*p2,0]
tarr=np.linspace(0.0, 2*P, 1e3)
mass = np.array([M1,M2, M3])
pos = np.array([body1Pos, body2Pos, body3Pos]).flatten()
velo = np.array([body1Velo, body2Velo, body3Velo]).flatten()
v0 = np.array([pos, velo]).flatten()
result=integrate.odeint(gs.df_Nbody,v0,tarr,args=(mass,))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.

# %%
p.plotter(result,1,1,1,proj=0)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\figure.py:2369: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "

# %%
p.plotter(result, 1,1,1,proj=2)

# %%
p.plotter(result, 1,1,1,proj=3)

# %%
p.plotter(result, 1,0,0,proj=4, tarr=tarr)
